# %% [markdown]
# # Artificial Intelligence Assignment #2-2<br> Training Vision Transformers (PyTorch)

# %% [markdown]
# Copyright (C) Computer Science & Engineering, Soongsil University. This material is for educational uses only. Some contents are based on the material provided by other paper/book authors and may be copyrighted by them (September 2025.)

# %% [markdown]
# **For understanding of this work, please carefully look at given PDF file.**
#
# Now, you're going to leave behind your implementations and instead migrate to one of popular deep learning frameworks, **PyTorch**. <br>
# In this notebook, you will learn to understand and build the basic components of Vision Tranformer(ViT). Then, you will try to classify images in the FashionMNIST datatset and explore the effects of different components of ViTs.
# <br>
# There are **2 sections**, and in each section, you need to follow the instructions to complete the skeleton codes and explain them.
#
# **Note**: certain details are missing or ambiguous on purpose, in order to test your knowledge on the related materials. However, if you really feel that something essential is missing and cannot proceed to the next step, then contact the teaching staff with clear description of your problem.
#
# ### Submitting your work:
# <font color=red>**DO NOT clear the final outputs**</font> so that TAs can grade both your code and results.
#
# ### Some helpful tutorials and references for assignment #2-2:
# - [1] Pytorch official documentation [[link]](https://pytorch.org/docs/stable/index.html).
# - [2] Stanford CS231n lectures [[link]](http://cs231n.stanford.edu/).
# - [3] Alexey Dosovitskiy et al., "An Image is Worth 16 x 16 Words: Transformers for Image Recognition at Scale", ICLR 2021 [[pdf]](https://arxiv.org/pdf/2010.11929.pdf).

# %% [markdown]
# ## 1. Building Vision Transformer
# Here, you will build the basic components of Vision Transformer(ViT). <br>
#
# ![Vision Transformer](imgs/ViT.png)
#
# Using the explanation and code provided as guidance, <br>
# Define each component of ViT. <br>
#
#
# #### ViT architecture:
# * ViT model consists with input patch embedding, positional embeddings, transformer encoder, etc.
# * Patch embedding
# * Positional embeddings
# * Transformer encoder with
#     * Attention module
#     * MLP module

# %%
import torch
import torch.nn as nn

# %% [markdown]
# ##### Patch Embed
#
# **Initialization**: When you create an instance of the PatchEmbedding class, you specify the image_size, patch_size, and in_channels. image_size is the height and width of the input image, patch_size is the size of each patch, and in_channels is the number of input image channels (e.g., 3 for RGB images).
#
# **Convolutional Projection**: Inside the PatchEmbedding class, a 2D convolutional layer (nn.Conv2d) is used to perform a patch-based projection. This convolutional layer has a kernel size of patch_size, which defines the size of each patch, and a stride of patch_size, which ensures that patches do not overlap. The convolutional layer effectively extracts image patches.
#
# **Reshaping**: After the convolutional projection, the output tensor is reshaped using view. It is transformed from a 4D tensor with dimensions (batch_size, in_channels, H, W) to a 3D tensor with dimensions (batch_size, num_patches, patch_dim). num_patches is the total number of non-overlapping patches in the image, and patch_dim is the number of output channels from the convolutional layer.

# %%
class PatchEmbed(nn.Module):
    """ Image to Patch Embedding
    """

    def __init__(self, img_size=224, patch_size=16, in_chans=3, embed_dim=768):
        super().__init__()
        num_patches = (img_size // patch_size) * (img_size // patch_size)
        self.img_size = img_size
        self.patch_size = patch_size
        self.num_patches = num_patches

        ##############################################################################
        #                           IMPLEMENT YOUR CODE                              #
        ##############################################################################

        self.proj = nn.Conv2d(in_chans, embed_dim, kernel_size=patch_size, stride=patch_size)

        ##############################################################################
        #                              END YOUR CODE                                 #
        ##############################################################################
    def forward(self, x):
        ##############################################################################
        #                           IMPLEMENT YOUR CODE                              #
        ##############################################################################

        B, C, H, W = x.shape
        x = self.proj(x).flatten(2).transpose(1, 2)

        ##############################################################################
        #                              END YOUR CODE                                 #
        ##############################################################################
        return x # output dimension must be: (batch size, number of patches, embed_dim)

# %% [markdown]
# ##### Attention
#
# **Initialization**
# * dim: The input dimension of the sequence. This is the dimensionality of the queries, keys, and values.
# * num_heads: The number of attention heads to use. Multi-head attention allows the model to focus on different parts of the input simultaneously.
#
# **Linear Projections (qkv and proj)**: The qkv linear layer takes the input sequence and projects it into three parts: queries (q), keys (k), and values (v). The output of this layer has a shape of (batch_size, sequence_length, 3 * dim).
#
# **Forward Pass (forward method)**: In the forward pass, the input tensor x is processed through the attention mechanism. Here's what happens:<br>
# * The linear projection qkv is applied to x, producing a tensor of shape (batch_size, sequence_length, 3 * dim).|
# * This tensor is reshaped to have dimensions (batch_size, sequence_length, 3, num_heads, head_dim). The permute operation rearranges the dimensions to (3, batch_size, num_heads, sequence_length, head_dim), making it suitable for multi-head attention.
# * The three parts, q, k, and v, are extracted from the reshaped tensor.
# * The attention scores are computed by taking the dot product of queries q and keys k. The result is scaled by self.scale.
# * The attention scores are passed through a softmax activation along the last dimension (sequence_length), producing attention weights.
# * The weighted sum of values v is computed using the attention weights.
# * The result is transposed and reshaped to its original shape, and then passed through the proj linear layer.
# * The final output is returned.

# %%
class Attention(nn.Module):
    def __init__(self, dim, num_heads=8):
        super().__init__()
        self.num_heads = num_heads
        head_dim = dim // num_heads
        self.scale = head_dim ** -0.5

        self.qkv = nn.Linear(dim, dim * 3)
        self.proj = nn.Linear(dim, dim)

    def forward(self, x):
        B, N, C = x.shape
        ##############################################################################
        #                           IMPLEMENT YOUR CODE                              #
        ##############################################################################

        qkv = self.qkv(x).reshape(B, N, 3, self.num_heads, C // self.num_heads).permute(2, 0, 3, 1, 4)
        q, k, v = qkv[0], qkv[1], qkv[2]

        attn = (q @ k.transpose(-2, -1)) * self.scale
        attn = attn.softmax(dim=-1)

        ##############################################################################
        #                              END YOUR CODE                                 #
        ##############################################################################

        x = (attn @ v).transpose(1, 2).reshape(B, N, C)
        x = self.proj(x)

        return x # output dimension must be: (batch size, number of patches, embed_dim)

# %% [markdown]
# ##### MLP
#
# The MLP module must consist of three layers:
# * fully conncted layer 1
# * activation layer
# * fully conncted layer 2

# %%
class Mlp(nn.Module):
    def __init__(self, in_features, hidden_features=None, out_features=None, act_layer=nn.GELU):
        super().__init__()
        out_features = out_features or in_features
        hidden_features = hidden_features or in_features

        ##############################################################################
        #                           IMPLEMENT YOUR CODE                              #
        ##############################################################################

        self.fc1 = nn.Linear(in_features, hidden_features)
        self.act = act_layer()
        self.fc2 = nn.Linear(hidden_features, out_features)

        ##############################################################################
        #                              END YOUR CODE                                 #
        ##############################################################################

    def forward(self, x):
        ##############################################################################
        #                           IMPLEMENT YOUR CODE                              #
        ##############################################################################

        x = self.fc1(x)
        x = self.act(x)
        x = self.fc2(x)

        ##############################################################################
        #                              END YOUR CODE                                 #
        ##############################################################################
        return x # output dimension must be: (batch size, number of patches, out_features)

# %% [markdown]
# ##### Transformer Block
# The transformer block contains the attention module and MLP module which have residual connections.
# Refer to the following image and build the forward pass.
#
# ![Transformer Block](imgs/TransformerBlock.png)

# %%
class Block(nn.Module):
    def __init__(self, dim, num_heads, mlp_ratio=4., act_layer=nn.GELU, norm_layer=nn.LayerNorm):
        super().__init__()
        self.norm1 = norm_layer(dim)
        self.attn = Attention(dim, num_heads=num_heads)
        self.norm2 = norm_layer(dim)
        mlp_hidden_dim = int(dim * mlp_ratio)
        self.mlp = Mlp(in_features=dim, hidden_features=mlp_hidden_dim,
                       act_layer=act_layer)

    def forward(self, x):
        ##############################################################################
        #                           IMPLEMENT YOUR CODE                              #
        ##############################################################################

        x = x + self.attn(self.norm1(x))
        x = x + self.mlp(self.norm2(x))

        ##############################################################################
        #                              END YOUR CODE                                 #
        ##############################################################################
        return x

# %% [markdown]
# ##### Vision Transformer
#
# Using all the components that you built above, **complete** the vision transformer class.

# %% [markdown]
# ### torch.cat
#
# Concatenates the given sequence of tensors along the specified dimension. All tensors must either have the same shape (except in the concatenating dimension) or be a 1-D empty tensor with size (0,).
#
# `torch.cat()` can be seen as an inverse operation for `torch.split()` and `torch.chunk()`.
#
# `torch.cat()` can be best understood via examples.

# %% [markdown]
# #### Parameters
#
# - **tensors** (sequence of Tensors): any Python sequence of tensors of the same type. Non-empty tensors provided must have the same shape, except in the concatenating dimension.
#
# - **dim** (int, optional): the dimension over which the tensors are concatenated.
#
# #### Keyword Arguments
#
# - **out** (Tensor, optional): the output tensor.

# %%
# example
x = torch.randn(2, 3)
x
# Out:
# tensor([[-1.4756,  1.5958,  0.5701],
#         [-2.8209,  0.5256, -0.5506]])

# %%
exam1 = torch.cat((x, x, x), 0)
exam1
# Out:
# tensor([[-1.4756,  1.5958,  0.5701],
#         [-2.8209,  0.5256, -0.5506],
#         [-1.4756,  1.5958,  0.5701],
#         [-2.8209,  0.5256, -0.5506],
#         [-1.4756,  1.5958,  0.5701],
#         [-2.8209,  0.5256, -0.5506]])

# %%
exam2 = torch.cat((x, x, x), 1)
exam2
# Out:
# tensor([[-1.4756,  1.5958,  0.5701, -1.4756,  1.5958,  0.5701, -1.4756,  1.5958,
#           0.5701],
#         [-2.8209,  0.5256, -0.5506, -2.8209,  0.5256, -0.5506, -2.8209,  0.5256,
#          -0.5506]])

# %%
class VisionTransformer(nn.Module):
    """ Vision Transformer """

    def __init__(self, img_size=28, patch_size=4, in_chans=1, num_classes=10, embed_dim=768, depth=12,
                 num_heads=12, mlp_ratio=4., norm_layer=nn.LayerNorm, ):
        super().__init__()
        self.num_features = self.embed_dim = embed_dim
        self.num_heads = num_heads
        self.depth = depth

        self.patch_embed = PatchEmbed(
            img_size=img_size, patch_size=patch_size, in_chans=in_chans, embed_dim=embed_dim)
        num_patches = self.patch_embed.num_patches

        self.cls_token = nn.Parameter(torch.zeros(1, 1, embed_dim))
        ##############################################################################
        #                           IMPLEMENT YOUR CODE                              #
        ##############################################################################
        # similarly to cls_token, define a learnable positional embedding that matches the patchified input token size.
        self.pos_embed = nn.Parameter(torch.zeros(1, num_patches + 1, embed_dim))

        ##############################################################################
        #                              END YOUR CODE                                 #
        ##############################################################################

        self.blocks = nn.ModuleList([
            Block(
                dim=embed_dim, num_heads=num_heads, mlp_ratio=mlp_ratio,  norm_layer=norm_layer)
            for i in range(depth)])
        self.norm = norm_layer(embed_dim)

        # Classifier head
        self.head = nn.Linear(
            embed_dim, num_classes) if num_classes > 0 else nn.Identity()

    def forward(self, x):
        ##############################################################################
        #                           IMPLEMENT YOUR CODE                              #
        ##############################################################################
        B = x.shape[0]

        # Patch Embedding
        x = self.patch_embed(x)

        # Concatenate class tokens to patch embedding
        cls_tokens = self.cls_token.expand(B, -1, -1)
        x = torch.cat((cls_tokens, x), dim=1)

        # Add positional embedding to patches
        x = x + self.pos_embed

        # Add positional embedding to patches
        for blk in self.blocks:
            x = blk(x)

        # Forward through encoder blocks
        x = self.norm(x)

        # Use class token for classification
        cls_token_output = x[:, 0]

        # Classifier head
        x = self.head(cls_token_output)


        ##############################################################################
        #                              END YOUR CODE                                 #
        ##############################################################################
        return x

# %% [markdown]
# ## 2. Training a small ViT model on FashionMNIST dataset.
#
# Define and Train a vision transformer on FashionMNIST dataset. **(You must reach above 85% for full points.)** <br>
# Train with at least 5 different hyperparameter settings varying the following ViT hyperparameters.
# Report the setting for the best performance.
#
# #### ViT hyperparameters:
# * patch_size
# * embed_dim
# * depth
# * num_heads
# * mlp_ratio
# * etc.

# %%
import numpy as np

from tqdm import tqdm, trange

import torch
import torch.nn as nn
from torch.optim import Adam
from torch.nn import CrossEntropyLoss
from torch.utils.data import DataLoader

from torchvision.transforms import ToTensor
from torchvision.datasets.mnist import FashionMNIST

# %%
def Train():
    ##############################################################################
    #                           IMPLEMENT YOUR CODE                              #
    ##############################################################################

    patch_size=4
    embed_dim=32
    depth=5
    num_heads=16
    mlp_ratio=4

    ##############################################################################
    #                              END YOUR CODE                                 #
    ##############################################################################

    # Loading data
    transform = ToTensor()

    train_set = FashionMNIST(root='./data', train=True, download=True, transform=transform)
    test_set = FashionMNIST(root='./data', train=False, download=True, transform=transform)

    train_loader = DataLoader(train_set, shuffle=True, batch_size=128)
    test_loader = DataLoader(test_set, shuffle=False, batch_size=128)

    # Defining model and training options
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    print("Using device: ", device, f"({torch.cuda.get_device_name(device)})" if torch.cuda.is_available() else "")

    model = VisionTransformer(patch_size=patch_size, embed_dim=embed_dim, depth=depth, num_heads=num_heads, mlp_ratio=mlp_ratio).to(device)
    model_path = './vit.pth'
    N_EPOCHS = 5
    LR = 0.005

    # Training loop
    optimizer = Adam(model.parameters(), lr=LR)
    criterion = CrossEntropyLoss()
    for epoch in trange(N_EPOCHS, desc="Training"):
        train_loss = 0.0
        for batch in tqdm(train_loader, desc=f"Epoch {epoch + 1} in training", leave=False):
            x, y = batch
            x, y = x.to(device), y.to(device)
            y_hat = model(x)
            loss = criterion(y_hat, y)

            train_loss += loss.detach().cpu().item() / len(train_loader)

            optimizer.zero_grad()
            loss.backward()
            optimizer.step()

        print(f"Epoch {epoch + 1}/{N_EPOCHS} loss: {train_loss:.2f}")

    # Test loop
    with torch.no_grad():
        correct, total = 0, 0
        test_loss = 0.0
        for batch in tqdm(test_loader, desc="Testing"):
            x, y = batch
            x, y = x.to(device), y.to(device)
            y_hat = model(x)
            loss = criterion(y_hat, y)
            test_loss += loss.detach().cpu().item() / len(test_loader)

            correct += torch.sum(torch.argmax(y_hat, dim=1) == y).detach().cpu().item()
            total += len(x)
        print(f"Test loss: {test_loss:.2f}")
        print(f"Test accuracy: {correct / total * 100:.2f}%")

    torch.save(model.state_dict(), model_path)
    print('Saved Trained Model.')

Train()
# Out:
# Using device:  cuda (Tesla T4)
# Training:   0%|          | 0/5 [00:00<?, ?it/s]
# Epoch 1 in training:   0%|          | 0/469 [00:00<?, ?it/s]
# Epoch 1 in training:   1%|          | 4/469 [00:00<00:14, 32.93it/s]
# Epoch 1 in training:   2%|▏         | 8/469 [00:00<00:13, 33.53it/s]
# Epoch 1 in training:   3%|▎         | 12/469 [00:00<00:13, 33.74it/s]
# Epoch 1 in training:   3%|▎         | 16/469 [00:00<00:13, 34.57it/s]
# Epoch 1 in training:   4%|▍         | 20/469 [00:00<00:12, 35.18it/s]
# Epoch 1 in training:   5%|▌         | 24/469 [00:00<00:12, 35.55it/s]
# Epoch 1 in training:   6%|▌         | 28/469 [00:00<00:12, 35.60it/s]
# Epoch 1 in training:   7%|▋         | 32/469 [00:00<00:12, 34.50it/s]
# Epoch 1 in training:   8%|▊         | 36/469 [00:01<00:12, 35.32it/s]
# Epoch 1 in training:   9%|▊         | 40/469 [00:01<00:11, 35.83it/s]
# Epoch 1 in training:   9%|▉         | 44/469 [00:01<00:11, 36.39it/s]
# Epoch 1 in training:  10%|█         | 48/469 [00:01<00:11, 36.72it/s]
# Epoch 1 in training:  11%|█         | 52/469 [00:01<00:11, 36.68it/s]
# Epoch 1 in training:  12%|█▏        | 56/469 [00:01<00:11, 36.66it/s]
# Epoch 1 in training:  13%|█▎        | 60/469 [00:01<00:11, 37.02it/s]
# Epoch 1 in training:  14%|█▎        | 64/469 [00:01<00:10, 37.12it/s]
# Epoch 1 in training:  14%|█▍        | 68/469 [00:01<00:11, 35.83it/s]
# Epoch 1 in training:  15%|█▌        | 72/469 [00:02<00:10, 36.24it/s]
# Epoch 1 in training:  16%|█▌        | 76/469 [00:02<00:10, 36.47it/s]
# Epoch 1 in training:  17%|█▋        | 80/469 [00:02<00:10, 36.90it/s]
# Epoch 1 in training:  18%|█▊        | 84/469 [00:02<00:10, 36.89it/s]
# Epoch 1 in training:  19%|█▉        | 88/469 [00:02<00:10, 36.78it/s]
# Epoch 1 in training:  20%|█▉        | 92/469 [00:02<00:10, 36.87it/s]
# Epoch 1 in training:  20%|██        | 96/469 [00:02<00:10, 36.58it/s]
# Epoch 1 in training:  21%|██▏       | 100/469 [00:02<00:10, 36.44it/s]
# Epoch 1 in training:  22%|██▏       | 104/469 [00:02<00:10, 35.95it/s]
# Epoch 1 in training:  23%|██▎       | 108/469 [00:03<00:10, 35.38it/s]
# Epoch 1 in training:  24%|██▍       | 112/469 [00:03<00:09, 36.03it/s]
# Epoch 1 in training:  25%|██▍       | 116/469 [00:03<00:09, 36.56it/s]
# Epoch 1 in training:  26%|██▌       | 120/469 [00:03<00:09, 36.68it/s]
# Epoch 1 in training:  26%|██▋       | 124/469 [00:03<00:09, 36.90it/s]
# Epoch 1 in training:  27%|██▋       | 128/469 [00:03<00:09, 37.25it/s]
# Epoch 1 in training:  28%|██▊       | 132/469 [00:03<00:09, 36.87it/s]
# Epoch 1 in training:  29%|██▉       | 136/469 [00:03<00:09, 36.88it/s]
# Epoch 1 in training:  30%|██▉       | 140/469 [00:03<00:09, 36.20it/s]
# Epoch 1 in training:  31%|███       | 144/469 [00:03<00:09, 35.14it/s]
# Epoch 1 in training:  32%|███▏      | 148/469 [00:04<00:08, 35.79it/s]
# Epoch 1 in training:  32%|███▏      | 152/469 [00:04<00:08, 36.31it/s]
# Epoch 1 in training:  33%|███▎      | 156/469 [00:04<00:08, 36.34it/s]
# Epoch 1 in training:  34%|███▍      | 160/469 [00:04<00:08, 36.65it/s]
# Epoch 1 in training:  35%|███▍      | 164/469 [00:04<00:08, 36.79it/s]
# Epoch 1 in training:  36%|███▌      | 168/469 [00:04<00:08, 36.40it/s]
# Epoch 1 in training:  37%|███▋      | 172/469 [00:04<00:08, 36.45it/s]
# Epoch 1 in training:  38%|███▊      | 176/469 [00:04<00:08, 36.11it/s]
# Epoch 1 in training:  38%|███▊      | 180/469 [00:04<00:08, 34.49it/s]
# Epoch 1 in training:  39%|███▉      | 184/469 [00:05<00:08, 35.24it/s]
# Epoch 1 in training:  40%|████      | 188/469 [00:05<00:07, 35.88it/s]
# Epoch 1 in training:  41%|████      | 192/469 [00:05<00:07, 36.00it/s]
# Epoch 1 in training:  42%|████▏     | 196/469 [00:05<00:07, 36.01it/s]
# Epoch 1 in training:  43%|████▎     | 200/469 [00:05<00:07, 36.31it/s]
# Epoch 1 in training:  43%|████▎     | 204/469 [00:05<00:07, 36.04it/s]
# Epoch 1 in training:  44%|████▍     | 208/469 [00:05<00:07, 36.31it/s]
# Epoch 1 in training:  45%|████▌     | 212/469 [00:05<00:07, 35.87it/s]
# Epoch 1 in training:  46%|████▌     | 216/469 [00:05<00:07, 35.92it/s]
# Epoch 1 in training:  47%|████▋     | 220/469 [00:06<00:07, 35.06it/s]
# Epoch 1 in training:  48%|████▊     | 224/469 [00:06<00:07, 33.47it/s]
# Epoch 1 in training:  49%|████▊     | 228/469 [00:06<00:07, 30.34it/s]
# Epoch 1 in training:  49%|████▉     | 232/469 [00:06<00:08, 29.56it/s]
# Epoch 1 in training:  50%|█████     | 236/469 [00:06<00:08, 28.96it/s]
# Epoch 1 in training:  51%|█████     | 239/469 [00:06<00:07, 28.82it/s]
# Epoch 1 in training:  52%|█████▏    | 242/469 [00:06<00:08, 28.37it/s]
# Epoch 1 in training:  52%|█████▏    | 245/469 [00:07<00:07, 28.34it/s]
# Epoch 1 in training:  53%|█████▎    | 248/469 [00:07<00:08, 27.11it/s]
# Epoch 1 in training:  54%|█████▎    | 251/469 [00:07<00:07, 27.82it/s]
# Epoch 1 in training:  54%|█████▍    | 255/469 [00:07<00:07, 28.87it/s]
# Epoch 1 in training:  55%|█████▌    | 258/469 [00:07<00:07, 29.11it/s]
# Epoch 1 in training:  56%|█████▌    | 261/469 [00:07<00:07, 27.78it/s]
# Epoch 1 in training:  56%|█████▋    | 264/469 [00:07<00:07, 26.95it/s]
# Epoch 1 in training:  57%|█████▋    | 267/469 [00:07<00:07, 26.37it/s]
# Epoch 1 in training:  58%|█████▊    | 270/469 [00:07<00:07, 25.42it/s]
# Epoch 1 in training:  58%|█████▊    | 273/469 [00:08<00:08, 24.36it/s]
# Epoch 1 in training:  59%|█████▉    | 276/469 [00:08<00:08, 24.01it/s]
# Epoch 1 in training:  60%|█████▉    | 280/469 [00:08<00:07, 25.80it/s]
# Epoch 1 in training:  61%|██████    | 284/469 [00:08<00:06, 28.42it/s]
# Epoch 1 in training:  61%|██████▏   | 288/469 [00:08<00:05, 30.75it/s]
# Epoch 1 in training:  62%|██████▏   | 292/469 [00:08<00:05, 31.45it/s]
# Epoch 1 in training:  63%|██████▎   | 296/469 [00:08<00:05, 32.58it/s]
# Epoch 1 in training:  64%|██████▍   | 300/469 [00:08<00:04, 33.82it/s]
# Epoch 1 in training:  65%|██████▍   | 304/469 [00:09<00:04, 34.52it/s]
# Epoch 1 in training:  66%|██████▌   | 308/469 [00:09<00:04, 34.17it/s]
# Epoch 1 in training:  67%|██████▋   | 312/469 [00:09<00:04, 34.93it/s]
# Epoch 1 in training:  67%|██████▋   | 316/469 [00:09<00:04, 34.64it/s]
# Epoch 1 in training:  68%|██████▊   | 320/469 [00:09<00:04, 35.04it/s]
# Epoch 1 in training:  69%|██████▉   | 324/469 [00:09<00:04, 35.41it/s]
# Epoch 1 in training:  70%|██████▉   | 328/469 [00:09<00:03, 35.34it/s]
# Epoch 1 in training:  71%|███████   | 332/469 [00:09<00:03, 35.27it/s]
# Epoch 1 in training:  72%|███████▏  | 336/469 [00:09<00:03, 35.46it/s]
# Epoch 1 in training:  72%|███████▏  | 340/469 [00:10<00:03, 35.74it/s]
# Epoch 1 in training:  73%|███████▎  | 344/469 [00:10<00:03, 35.53it/s]
# Epoch 1 in training:  74%|███████▍  | 348/469 [00:10<00:03, 34.51it/s]
# Epoch 1 in training:  75%|███████▌  | 352/469 [00:10<00:03, 35.07it/s]
# Epoch 1 in training:  76%|███████▌  | 356/469 [00:10<00:03, 35.53it/s]
# Epoch 1 in training:  77%|███████▋  | 360/469 [00:10<00:03, 35.97it/s]
# Epoch 1 in training:  78%|███████▊  | 364/469 [00:10<00:02, 35.76it/s]
# Epoch 1 in training:  78%|███████▊  | 368/469 [00:10<00:02, 35.61it/s]
# Epoch 1 in training:  79%|███████▉  | 372/469 [00:10<00:02, 35.66it/s]
# Epoch 1 in training:  80%|████████  | 376/469 [00:11<00:02, 35.75it/s]
# Epoch 1 in training:  81%|████████  | 380/469 [00:11<00:02, 35.92it/s]
# Epoch 1 in training:  82%|████████▏ | 384/469 [00:11<00:02, 34.99it/s]
# Epoch 1 in training:  83%|████████▎ | 388/469 [00:11<00:02, 35.37it/s]
# Epoch 1 in training:  84%|████████▎ | 392/469 [00:11<00:02, 35.89it/s]
# Epoch 1 in training:  84%|████████▍ | 396/469 [00:11<00:02, 36.32it/s]
# Epoch 1 in training:  85%|████████▌ | 400/469 [00:11<00:01, 36.06it/s]
# Epoch 1 in training:  86%|████████▌ | 404/469 [00:11<00:01, 35.91it/s]
# Epoch 1 in training:  87%|████████▋ | 408/469 [00:11<00:01, 35.92it/s]
# Epoch 1 in training:  88%|████████▊ | 412/469 [00:12<00:01, 36.22it/s]
# Epoch 1 in training:  89%|████████▊ | 416/469 [00:12<00:01, 36.47it/s]
# Epoch 1 in training:  90%|████████▉ | 420/469 [00:12<00:01, 35.26it/s]
# Epoch 1 in training:  90%|█████████ | 424/469 [00:12<00:01, 35.68it/s]
# Epoch 1 in training:  91%|█████████▏| 428/469 [00:12<00:01, 35.82it/s]
# Epoch 1 in training:  92%|█████████▏| 432/469 [00:12<00:01, 36.00it/s]
# Epoch 1 in training:  93%|█████████▎| 436/469 [00:12<00:00, 35.93it/s]
# Epoch 1 in training:  94%|█████████▍| 440/469 [00:12<00:00, 35.56it/s]
# Epoch 1 in training:  95%|█████████▍| 444/469 [00:12<00:00, 35.87it/s]
# Epoch 1 in training:  96%|█████████▌| 448/469 [00:13<00:00, 35.74it/s]
# Epoch 1 in training:  96%|█████████▋| 452/469 [00:13<00:00, 35.96it/s]
# Epoch 1 in training:  97%|█████████▋| 456/469 [00:13<00:00, 35.11it/s]
# Epoch 1 in training:  98%|█████████▊| 460/469 [00:13<00:00, 35.46it/s]
# Epoch 1 in training:  99%|█████████▉| 464/469 [00:13<00:00, 35.85it/s]
# Epoch 1 in training: 100%|█████████▉| 468/469 [00:13<00:00, 36.05it/s]
# Training:  20%|██        | 1/5 [00:13<00:54, 13.66s/it]
# Epoch 1/5 loss: 0.81
# Epoch 2 in training:   0%|          | 0/469 [00:00<?, ?it/s]
# Epoch 2 in training:   1%|          | 4/469 [00:00<00:12, 35.94it/s]
# Epoch 2 in training:   2%|▏         | 8/469 [00:00<00:13, 35.09it/s]
# Epoch 2 in training:   3%|▎         | 12/469 [00:00<00:12, 35.34it/s]
# Epoch 2 in training:   3%|▎         | 16/469 [00:00<00:12, 35.70it/s]
# Epoch 2 in training:   4%|▍         | 20/469 [00:00<00:12, 36.20it/s]
# Epoch 2 in training:   5%|▌         | 24/469 [00:00<00:12, 34.98it/s]
# Epoch 2 in training:   6%|▌         | 28/469 [00:00<00:12, 35.64it/s]
# Epoch 2 in training:   7%|▋         | 32/469 [00:00<00:12, 36.10it/s]
# Epoch 2 in training:   8%|▊         | 36/469 [00:01<00:12, 35.97it/s]
# Epoch 2 in training:   9%|▊         | 40/469 [00:01<00:11, 36.09it/s]
# Epoch 2 in training:   9%|▉         | 44/469 [00:01<00:11, 35.73it/s]
# Epoch 2 in training:  10%|█         | 48/469 [00:01<00:11, 36.12it/s]
# Epoch 2 in training:  11%|█         | 52/469 [00:01<00:11, 36.59it/s]
# Epoch 2 in training:  12%|█▏        | 56/469 [00:01<00:11, 37.09it/s]
# Epoch 2 in training:  13%|█▎        | 60/469 [00:01<00:11, 35.78it/s]
# Epoch 2 in training:  14%|█▎        | 64/469 [00:01<00:11, 36.31it/s]
# Epoch 2 in training:  14%|█▍        | 68/469 [00:01<00:10, 36.88it/s]
# Epoch 2 in training:  15%|█▌        | 72/469 [00:01<00:10, 37.20it/s]
# Epoch 2 in training:  16%|█▌        | 76/469 [00:02<00:10, 37.37it/s]
# Epoch 2 in training:  17%|█▋        | 80/469 [00:02<00:10, 36.77it/s]
# Epoch 2 in training:  18%|█▊        | 84/469 [00:02<00:10, 36.91it/s]
# Epoch 2 in training:  19%|█▉        | 88/469 [00:02<00:10, 37.07it/s]
# Epoch 2 in training:  20%|█▉        | 92/469 [00:02<00:10, 37.20it/s]
# Epoch 2 in training:  20%|██        | 96/469 [00:02<00:10, 36.91it/s]
# Epoch 2 in training:  21%|██▏       | 100/469 [00:02<00:10, 35.48it/s]
# Epoch 2 in training:  22%|██▏       | 104/469 [00:02<00:10, 35.98it/s]
# Epoch 2 in training:  23%|██▎       | 108/469 [00:02<00:09, 36.18it/s]
# Epoch 2 in training:  24%|██▍       | 112/469 [00:03<00:09, 36.32it/s]
# Epoch 2 in training:  25%|██▍       | 116/469 [00:03<00:09, 36.06it/s]
# Epoch 2 in training:  26%|██▌       | 120/469 [00:03<00:09, 36.43it/s]
# Epoch 2 in training:  26%|██▋       | 124/469 [00:03<00:09, 36.81it/s]
# Epoch 2 in training:  27%|██▋       | 128/469 [00:03<00:09, 36.84it/s]
# Epoch 2 in training:  28%|██▊       | 132/469 [00:03<00:09, 36.47it/s]
# Epoch 2 in training:  29%|██▉       | 136/469 [00:03<00:09, 35.58it/s]
# Epoch 2 in training:  30%|██▉       | 140/469 [00:03<00:09, 35.89it/s]
# Epoch 2 in training:  31%|███       | 144/469 [00:03<00:09, 35.25it/s]
# Epoch 2 in training:  32%|███▏      | 148/469 [00:04<00:09, 35.63it/s]
# Epoch 2 in training:  32%|███▏      | 152/469 [00:04<00:08, 35.63it/s]
# Epoch 2 in training:  33%|███▎      | 156/469 [00:04<00:08, 36.06it/s]
# Epoch 2 in training:  34%|███▍      | 160/469 [00:04<00:08, 36.45it/s]
# Epoch 2 in training:  35%|███▍      | 164/469 [00:04<00:08, 35.74it/s]
# Epoch 2 in training:  36%|███▌      | 168/469 [00:04<00:09, 30.98it/s]
# Epoch 2 in training:  37%|███▋      | 172/469 [00:04<00:10, 28.52it/s]
# Epoch 2 in training:  37%|███▋      | 175/469 [00:04<00:10, 28.17it/s]
# Epoch 2 in training:  38%|███▊      | 178/469 [00:05<00:10, 27.95it/s]
# Epoch 2 in training:  39%|███▊      | 181/469 [00:05<00:10, 27.26it/s]
# Epoch 2 in training:  39%|███▉      | 184/469 [00:05<00:10, 27.08it/s]
# Epoch 2 in training:  40%|███▉      | 187/469 [00:05<00:10, 26.54it/s]
# Epoch 2 in training:  41%|████      | 190/469 [00:05<00:10, 27.00it/s]
# Epoch 2 in training:  41%|████      | 193/469 [00:05<00:10, 27.56it/s]
# Epoch 2 in training:  42%|████▏     | 196/469 [00:05<00:09, 28.08it/s]
# Epoch 2 in training:  42%|████▏     | 199/469 [00:05<00:09, 27.80it/s]
# Epoch 2 in training:  43%|████▎     | 202/469 [00:05<00:09, 27.27it/s]
# Epoch 2 in training:  44%|████▎     | 205/469 [00:06<00:10, 25.77it/s]
# Epoch 2 in training:  44%|████▍     | 208/469 [00:06<00:09, 26.14it/s]
# Epoch 2 in training:  45%|████▍     | 211/469 [00:06<00:10, 24.81it/s]
# Epoch 2 in training:  46%|████▌     | 214/469 [00:06<00:10, 24.47it/s]
# Epoch 2 in training:  46%|████▋     | 217/469 [00:06<00:10, 23.83it/s]
# Epoch 2 in training:  47%|████▋     | 221/469 [00:06<00:09, 27.06it/s]
# Epoch 2 in training:  48%|████▊     | 225/469 [00:06<00:08, 29.61it/s]
# Epoch 2 in training:  49%|████▉     | 229/469 [00:06<00:07, 30.81it/s]
# Epoch 2 in training:  50%|████▉     | 233/469 [00:07<00:07, 32.28it/s]
# Epoch 2 in training:  51%|█████     | 237/469 [00:07<00:06, 33.16it/s]
# Epoch 2 in training:  51%|█████▏    | 241/469 [00:07<00:06, 34.07it/s]
# Epoch 2 in training:  52%|█████▏    | 245/469 [00:07<00:06, 34.62it/s]
# Epoch 2 in training:  53%|█████▎    | 249/469 [00:07<00:06, 35.19it/s]
# Epoch 2 in training:  54%|█████▍    | 253/469 [00:07<00:06, 35.63it/s]
# Epoch 2 in training:  55%|█████▍    | 257/469 [00:07<00:05, 35.75it/s]
# Epoch 2 in training:  56%|█████▌    | 261/469 [00:07<00:05, 36.06it/s]
# Epoch 2 in training:  57%|█████▋    | 265/469 [00:07<00:05, 34.97it/s]
# Epoch 2 in training:  57%|█████▋    | 269/469 [00:08<00:05, 35.33it/s]
# Epoch 2 in training:  58%|█████▊    | 273/469 [00:08<00:05, 35.12it/s]
# Epoch 2 in training:  59%|█████▉    | 277/469 [00:08<00:05, 35.25it/s]
# Epoch 2 in training:  60%|█████▉    | 281/469 [00:08<00:05, 35.42it/s]
# Epoch 2 in training:  61%|██████    | 285/469 [00:08<00:05, 35.62it/s]
# Epoch 2 in training:  62%|██████▏   | 289/469 [00:08<00:05, 35.95it/s]
# Epoch 2 in training:  62%|██████▏   | 293/469 [00:08<00:04, 35.97it/s]
# Epoch 2 in training:  63%|██████▎   | 297/469 [00:08<00:04, 35.93it/s]
# Epoch 2 in training:  64%|██████▍   | 301/469 [00:08<00:04, 35.98it/s]
# Epoch 2 in training:  65%|██████▌   | 305/469 [00:09<00:04, 34.71it/s]
# Epoch 2 in training:  66%|██████▌   | 309/469 [00:09<00:04, 34.81it/s]
# Epoch 2 in training:  67%|██████▋   | 313/469 [00:09<00:04, 35.19it/s]
# Epoch 2 in training:  68%|██████▊   | 317/469 [00:09<00:04, 35.39it/s]
# Epoch 2 in training:  68%|██████▊   | 321/469 [00:09<00:04, 35.68it/s]
# Epoch 2 in training:  69%|██████▉   | 325/469 [00:09<00:03, 36.10it/s]
# Epoch 2 in training:  70%|███████   | 329/469 [00:09<00:03, 35.99it/s]
# Epoch 2 in training:  71%|███████   | 333/469 [00:09<00:03, 36.20it/s]
# Epoch 2 in training:  72%|███████▏  | 337/469 [00:09<00:03, 36.18it/s]
# Epoch 2 in training:  73%|███████▎  | 341/469 [00:10<00:03, 35.05it/s]
# Epoch 2 in training:  74%|███████▎  | 345/469 [00:10<00:03, 35.01it/s]
# Epoch 2 in training:  74%|███████▍  | 349/469 [00:10<00:03, 35.25it/s]
# Epoch 2 in training:  75%|███████▌  | 353/469 [00:10<00:03, 35.37it/s]
# Epoch 2 in training:  76%|███████▌  | 357/469 [00:10<00:03, 35.76it/s]
# Epoch 2 in training:  77%|███████▋  | 361/469 [00:10<00:02, 36.12it/s]
# Epoch 2 in training:  78%|███████▊  | 365/469 [00:10<00:02, 35.77it/s]
# Epoch 2 in training:  79%|███████▊  | 369/469 [00:10<00:02, 36.10it/s]
# Epoch 2 in training:  80%|███████▉  | 373/469 [00:10<00:02, 35.95it/s]
# Epoch 2 in training:  80%|████████  | 377/469 [00:11<00:02, 34.60it/s]
# Epoch 2 in training:  81%|████████  | 381/469 [00:11<00:02, 34.86it/s]
# Epoch 2 in training:  82%|████████▏ | 385/469 [00:11<00:02, 35.28it/s]
# Epoch 2 in training:  83%|████████▎ | 389/469 [00:11<00:02, 35.45it/s]
# Epoch 2 in training:  84%|████████▍ | 393/469 [00:11<00:02, 35.63it/s]
# Epoch 2 in training:  85%|████████▍ | 397/469 [00:11<00:02, 35.82it/s]
# Epoch 2 in training:  86%|████████▌ | 401/469 [00:11<00:01, 35.66it/s]
# Epoch 2 in training:  86%|████████▋ | 405/469 [00:11<00:01, 36.09it/s]
# Epoch 2 in training:  87%|████████▋ | 409/469 [00:12<00:01, 35.95it/s]
# Epoch 2 in training:  88%|████████▊ | 413/469 [00:12<00:01, 34.31it/s]
# Epoch 2 in training:  89%|████████▉ | 417/469 [00:12<00:01, 34.87it/s]
# Epoch 2 in training:  90%|████████▉ | 421/469 [00:12<00:01, 35.30it/s]
# Epoch 2 in training:  91%|█████████ | 425/469 [00:12<00:01, 35.51it/s]
# Epoch 2 in training:  91%|█████████▏| 429/469 [00:12<00:01, 35.63it/s]
# Epoch 2 in training:  92%|█████████▏| 433/469 [00:12<00:01, 35.77it/s]
# Epoch 2 in training:  93%|█████████▎| 437/469 [00:12<00:00, 35.57it/s]
# Epoch 2 in training:  94%|█████████▍| 441/469 [00:12<00:00, 35.93it/s]
# Epoch 2 in training:  95%|█████████▍| 445/469 [00:13<00:00, 36.14it/s]
# Epoch 2 in training:  96%|█████████▌| 449/469 [00:13<00:00, 34.63it/s]
# Epoch 2 in training:  97%|█████████▋| 453/469 [00:13<00:00, 35.22it/s]
# Epoch 2 in training:  97%|█████████▋| 457/469 [00:13<00:00, 35.40it/s]
# Epoch 2 in training:  98%|█████████▊| 461/469 [00:13<00:00, 35.59it/s]
# Epoch 2 in training:  99%|█████████▉| 465/469 [00:13<00:00, 35.93it/s]
# Epoch 2 in training: 100%|██████████| 469/469 [00:13<00:00, 36.26it/s]
# Training:  40%|████      | 2/5 [00:27<00:41, 13.69s/it]
# Epoch 2/5 loss: 0.48
# Epoch 3 in training:   0%|          | 0/469 [00:00<?, ?it/s]
# Epoch 3 in training:   1%|          | 4/469 [00:00<00:13, 35.54it/s]
# Epoch 3 in training:   2%|▏         | 8/469 [00:00<00:12, 36.09it/s]
# Epoch 3 in training:   3%|▎         | 12/469 [00:00<00:12, 36.14it/s]
# Epoch 3 in training:   3%|▎         | 16/469 [00:00<00:13, 33.89it/s]
# Epoch 3 in training:   4%|▍         | 20/469 [00:00<00:12, 34.87it/s]
# Epoch 3 in training:   5%|▌         | 24/469 [00:00<00:12, 35.29it/s]
# Epoch 3 in training:   6%|▌         | 28/469 [00:00<00:12, 35.59it/s]
# Epoch 3 in training:   7%|▋         | 32/469 [00:00<00:12, 35.88it/s]
# Epoch 3 in training:   8%|▊         | 36/469 [00:01<00:12, 36.06it/s]
# Epoch 3 in training:   9%|▊         | 40/469 [00:01<00:11, 36.27it/s]
# Epoch 3 in training:   9%|▉         | 44/469 [00:01<00:11, 36.35it/s]
# Epoch 3 in training:  10%|█         | 48/469 [00:01<00:11, 36.71it/s]
# Epoch 3 in training:  11%|█         | 52/469 [00:01<00:11, 36.00it/s]
# Epoch 3 in training:  12%|█▏        | 56/469 [00:01<00:11, 35.08it/s]
# Epoch 3 in training:  13%|█▎        | 60/469 [00:01<00:11, 34.49it/s]
# Epoch 3 in training:  14%|█▎        | 64/469 [00:01<00:11, 35.05it/s]
# Epoch 3 in training:  14%|█▍        | 68/469 [00:01<00:11, 35.58it/s]
# Epoch 3 in training:  15%|█▌        | 72/469 [00:02<00:11, 35.81it/s]
# Epoch 3 in training:  16%|█▌        | 76/469 [00:02<00:10, 36.19it/s]
# Epoch 3 in training:  17%|█▋        | 80/469 [00:02<00:10, 36.24it/s]
# Epoch 3 in training:  18%|█▊        | 84/469 [00:02<00:10, 36.17it/s]
# Epoch 3 in training:  19%|█▉        | 88/469 [00:02<00:10, 35.72it/s]
# Epoch 3 in training:  20%|█▉        | 92/469 [00:02<00:10, 34.97it/s]
# Epoch 3 in training:  20%|██        | 96/469 [00:02<00:10, 35.55it/s]
# Epoch 3 in training:  21%|██▏       | 100/469 [00:02<00:10, 36.18it/s]
# Epoch 3 in training:  22%|██▏       | 104/469 [00:02<00:09, 36.79it/s]
# Epoch 3 in training:  23%|██▎       | 108/469 [00:03<00:11, 31.87it/s]
# Epoch 3 in training:  24%|██▍       | 112/469 [00:03<00:11, 30.67it/s]
# Epoch 3 in training:  25%|██▍       | 116/469 [00:03<00:11, 30.14it/s]
# Epoch 3 in training:  26%|██▌       | 120/469 [00:03<00:11, 29.86it/s]
# Epoch 3 in training:  26%|██▋       | 124/469 [00:03<00:11, 28.93it/s]
# Epoch 3 in training:  27%|██▋       | 127/469 [00:03<00:11, 28.89it/s]
# Epoch 3 in training:  28%|██▊       | 130/469 [00:03<00:11, 28.61it/s]
# Epoch 3 in training:  29%|██▊       | 134/469 [00:03<00:11, 29.35it/s]
# Epoch 3 in training:  29%|██▉       | 137/469 [00:04<00:11, 29.44it/s]
# Epoch 3 in training:  30%|███       | 141/469 [00:04<00:10, 29.89it/s]
# Epoch 3 in training:  31%|███       | 144/469 [00:04<00:11, 29.18it/s]
# Epoch 3 in training:  31%|███▏      | 147/469 [00:04<00:11, 27.00it/s]
# Epoch 3 in training:  32%|███▏      | 150/469 [00:04<00:11, 26.96it/s]
# Epoch 3 in training:  33%|███▎      | 153/469 [00:04<00:12, 24.69it/s]
# Epoch 3 in training:  33%|███▎      | 156/469 [00:04<00:12, 24.50it/s]
# Epoch 3 in training:  34%|███▍      | 159/469 [00:04<00:12, 24.02it/s]
# Epoch 3 in training:  35%|███▍      | 163/469 [00:05<00:11, 27.31it/s]
# Epoch 3 in training:  36%|███▌      | 167/469 [00:05<00:10, 29.98it/s]
# Epoch 3 in training:  36%|███▋      | 171/469 [00:05<00:09, 31.90it/s]
# Epoch 3 in training:  37%|███▋      | 175/469 [00:05<00:08, 33.06it/s]
# Epoch 3 in training:  38%|███▊      | 179/469 [00:05<00:08, 33.73it/s]
# Epoch 3 in training:  39%|███▉      | 183/469 [00:05<00:08, 34.60it/s]
# Epoch 3 in training:  40%|███▉      | 187/469 [00:05<00:08, 33.88it/s]
# Epoch 3 in training:  41%|████      | 191/469 [00:05<00:07, 34.85it/s]
# Epoch 3 in training:  42%|████▏     | 195/469 [00:05<00:07, 35.38it/s]
# Epoch 3 in training:  42%|████▏     | 199/469 [00:06<00:07, 35.54it/s]
# Epoch 3 in training:  43%|████▎     | 203/469 [00:06<00:07, 35.80it/s]
# Epoch 3 in training:  44%|████▍     | 207/469 [00:06<00:07, 35.92it/s]
# Epoch 3 in training:  45%|████▍     | 211/469 [00:06<00:07, 35.55it/s]
# Epoch 3 in training:  46%|████▌     | 215/469 [00:06<00:07, 35.73it/s]
# Epoch 3 in training:  47%|████▋     | 219/469 [00:06<00:06, 35.95it/s]
# Epoch 3 in training:  48%|████▊     | 223/469 [00:06<00:07, 34.19it/s]
# Epoch 3 in training:  48%|████▊     | 227/469 [00:06<00:07, 34.26it/s]
# Epoch 3 in training:  49%|████▉     | 231/469 [00:07<00:07, 33.79it/s]
# Epoch 3 in training:  50%|█████     | 235/469 [00:07<00:06, 34.40it/s]
# Epoch 3 in training:  51%|█████     | 239/469 [00:07<00:06, 34.98it/s]
# Epoch 3 in training:  52%|█████▏    | 243/469 [00:07<00:06, 35.45it/s]
# Epoch 3 in training:  53%|█████▎    | 247/469 [00:07<00:06, 35.24it/s]
# Epoch 3 in training:  54%|█████▎    | 251/469 [00:07<00:06, 35.50it/s]
# Epoch 3 in training:  54%|█████▍    | 255/469 [00:07<00:05, 35.75it/s]
# Epoch 3 in training:  55%|█████▌    | 259/469 [00:07<00:06, 34.96it/s]
# Epoch 3 in training:  56%|█████▌    | 263/469 [00:07<00:05, 35.47it/s]
# Epoch 3 in training:  57%|█████▋    | 267/469 [00:08<00:05, 35.42it/s]
# Epoch 3 in training:  58%|█████▊    | 271/469 [00:08<00:05, 35.55it/s]
# Epoch 3 in training:  59%|█████▊    | 275/469 [00:08<00:05, 35.96it/s]
# Epoch 3 in training:  59%|█████▉    | 279/469 [00:08<00:05, 36.06it/s]
# Epoch 3 in training:  60%|██████    | 283/469 [00:08<00:05, 35.65it/s]
# Epoch 3 in training:  61%|██████    | 287/469 [00:08<00:05, 35.93it/s]
# Epoch 3 in training:  62%|██████▏   | 291/469 [00:08<00:04, 36.26it/s]
# Epoch 3 in training:  63%|██████▎   | 295/469 [00:08<00:04, 35.51it/s]
# Epoch 3 in training:  64%|██████▍   | 299/469 [00:08<00:04, 35.90it/s]
# Epoch 3 in training:  65%|██████▍   | 303/469 [00:09<00:04, 35.99it/s]
# Epoch 3 in training:  65%|██████▌   | 307/469 [00:09<00:04, 35.88it/s]
# Epoch 3 in training:  66%|██████▋   | 311/469 [00:09<00:04, 36.04it/s]
# Epoch 3 in training:  67%|██████▋   | 315/469 [00:09<00:04, 35.91it/s]
# Epoch 3 in training:  68%|██████▊   | 319/469 [00:09<00:04, 35.58it/s]
# Epoch 3 in training:  69%|██████▉   | 323/469 [00:09<00:04, 35.38it/s]
# Epoch 3 in training:  70%|██████▉   | 327/469 [00:09<00:03, 35.52it/s]
# Epoch 3 in training:  71%|███████   | 331/469 [00:09<00:03, 34.62it/s]
# Epoch 3 in training:  71%|███████▏  | 335/469 [00:09<00:03, 34.99it/s]
# Epoch 3 in training:  72%|███████▏  | 339/469 [00:10<00:03, 35.15it/s]
# Epoch 3 in training:  73%|███████▎  | 343/469 [00:10<00:03, 35.09it/s]
# Epoch 3 in training:  74%|███████▍  | 347/469 [00:10<00:03, 35.39it/s]
# Epoch 3 in training:  75%|███████▍  | 351/469 [00:10<00:03, 35.78it/s]
# Epoch 3 in training:  76%|███████▌  | 355/469 [00:10<00:03, 35.48it/s]
# Epoch 3 in training:  77%|███████▋  | 359/469 [00:10<00:03, 35.78it/s]
# Epoch 3 in training:  77%|███████▋  | 363/469 [00:10<00:02, 35.79it/s]
# Epoch 3 in training:  78%|███████▊  | 367/469 [00:10<00:02, 35.52it/s]
# Epoch 3 in training:  79%|███████▉  | 371/469 [00:10<00:02, 35.10it/s]
# Epoch 3 in training:  80%|███████▉  | 375/469 [00:11<00:02, 33.36it/s]
# Epoch 3 in training:  81%|████████  | 379/469 [00:11<00:02, 33.77it/s]
# Epoch 3 in training:  82%|████████▏ | 383/469 [00:11<00:02, 34.42it/s]
# Epoch 3 in training:  83%|████████▎ | 387/469 [00:11<00:02, 34.80it/s]
# Epoch 3 in training:  83%|████████▎ | 391/469 [00:11<00:02, 34.93it/s]
# Epoch 3 in training:  84%|████████▍ | 395/469 [00:11<00:02, 35.51it/s]
# Epoch 3 in training:  85%|████████▌ | 399/469 [00:11<00:02, 34.73it/s]
# Epoch 3 in training:  86%|████████▌ | 403/469 [00:11<00:01, 34.52it/s]
# Epoch 3 in training:  87%|████████▋ | 407/469 [00:11<00:01, 33.66it/s]
# Epoch 3 in training:  88%|████████▊ | 411/469 [00:12<00:01, 33.34it/s]
# Epoch 3 in training:  88%|████████▊ | 415/469 [00:12<00:01, 34.13it/s]
# Epoch 3 in training:  89%|████████▉ | 419/469 [00:12<00:01, 34.08it/s]
# Epoch 3 in training:  90%|█████████ | 423/469 [00:12<00:01, 33.88it/s]
# Epoch 3 in training:  91%|█████████ | 427/469 [00:12<00:01, 34.73it/s]
# Epoch 3 in training:  92%|█████████▏| 431/469 [00:12<00:01, 35.28it/s]
# Epoch 3 in training:  93%|█████████▎| 435/469 [00:12<00:00, 35.52it/s]
# Epoch 3 in training:  94%|█████████▎| 439/469 [00:12<00:00, 34.23it/s]
# Epoch 3 in training:  94%|█████████▍| 443/469 [00:13<00:00, 34.83it/s]
# Epoch 3 in training:  95%|█████████▌| 447/469 [00:13<00:00, 35.19it/s]
# Epoch 3 in training:  96%|█████████▌| 451/469 [00:13<00:00, 35.63it/s]
# Epoch 3 in training:  97%|█████████▋| 455/469 [00:13<00:00, 35.46it/s]
# Epoch 3 in training:  98%|█████████▊| 459/469 [00:13<00:00, 35.17it/s]
# Epoch 3 in training:  99%|█████████▊| 463/469 [00:13<00:00, 35.57it/s]
# Epoch 3 in training: 100%|█████████▉| 467/469 [00:13<00:00, 35.76it/s]
# Training:  60%|██████    | 3/5 [00:41<00:27, 13.72s/it]
# Epoch 3/5 loss: 0.43
# Epoch 4 in training:   0%|          | 0/469 [00:00<?, ?it/s]
# Epoch 4 in training:   1%|          | 4/469 [00:00<00:12, 36.73it/s]
# Epoch 4 in training:   2%|▏         | 8/469 [00:00<00:13, 33.88it/s]
# Epoch 4 in training:   3%|▎         | 12/469 [00:00<00:12, 35.34it/s]
# Epoch 4 in training:   3%|▎         | 16/469 [00:00<00:12, 36.16it/s]
# Epoch 4 in training:   4%|▍         | 20/469 [00:00<00:12, 36.37it/s]
# Epoch 4 in training:   5%|▌         | 24/469 [00:00<00:12, 35.93it/s]
# Epoch 4 in training:   6%|▌         | 28/469 [00:00<00:12, 36.03it/s]
# Epoch 4 in training:   7%|▋         | 32/469 [00:00<00:12, 36.14it/s]
# Epoch 4 in training:   8%|▊         | 36/469 [00:00<00:11, 36.34it/s]
# Epoch 4 in training:   9%|▊         | 40/469 [00:01<00:11, 36.69it/s]
# Epoch 4 in training:   9%|▉         | 44/469 [00:01<00:12, 33.70it/s]
# Epoch 4 in training:  10%|█         | 48/469 [00:01<00:13, 30.41it/s]
# Epoch 4 in training:  11%|█         | 52/469 [00:01<00:14, 29.63it/s]
# Epoch 4 in training:  12%|█▏        | 56/469 [00:01<00:14, 29.16it/s]
# Epoch 4 in training:  13%|█▎        | 59/469 [00:01<00:14, 28.95it/s]
# Epoch 4 in training:  13%|█▎        | 62/469 [00:01<00:14, 28.73it/s]
# Epoch 4 in training:  14%|█▍        | 65/469 [00:02<00:14, 28.41it/s]
# Epoch 4 in training:  14%|█▍        | 68/469 [00:02<00:14, 28.44it/s]
# Epoch 4 in training:  15%|█▌        | 72/469 [00:02<00:13, 28.91it/s]
# Epoch 4 in training:  16%|█▌        | 75/469 [00:02<00:13, 29.03it/s]
# Epoch 4 in training:  17%|█▋        | 79/469 [00:02<00:13, 29.67it/s]
# Epoch 4 in training:  17%|█▋        | 82/469 [00:02<00:13, 28.62it/s]
# Epoch 4 in training:  18%|█▊        | 85/469 [00:02<00:14, 26.83it/s]
# Epoch 4 in training:  19%|█▉        | 88/469 [00:02<00:14, 26.76it/s]
# Epoch 4 in training:  19%|█▉        | 91/469 [00:02<00:14, 25.28it/s]
# Epoch 4 in training:  20%|██        | 94/469 [00:03<00:15, 24.43it/s]
# Epoch 4 in training:  21%|██        | 97/469 [00:03<00:14, 24.80it/s]
# Epoch 4 in training:  22%|██▏       | 101/469 [00:03<00:13, 27.18it/s]
# Epoch 4 in training:  22%|██▏       | 105/469 [00:03<00:12, 29.86it/s]
# Epoch 4 in training:  23%|██▎       | 109/469 [00:03<00:11, 31.92it/s]
# Epoch 4 in training:  24%|██▍       | 113/469 [00:03<00:10, 32.59it/s]
# Epoch 4 in training:  25%|██▍       | 117/469 [00:03<00:10, 33.73it/s]
# Epoch 4 in training:  26%|██▌       | 121/469 [00:03<00:10, 34.68it/s]
# Epoch 4 in training:  27%|██▋       | 125/469 [00:04<00:09, 35.10it/s]
# Epoch 4 in training:  28%|██▊       | 129/469 [00:04<00:09, 35.53it/s]
# Epoch 4 in training:  28%|██▊       | 133/469 [00:04<00:09, 35.70it/s]
# Epoch 4 in training:  29%|██▉       | 137/469 [00:04<00:09, 34.67it/s]
# Epoch 4 in training:  30%|███       | 141/469 [00:04<00:09, 35.02it/s]
# Epoch 4 in training:  31%|███       | 145/469 [00:04<00:09, 35.59it/s]
# Epoch 4 in training:  32%|███▏      | 149/469 [00:04<00:09, 35.43it/s]
# Epoch 4 in training:  33%|███▎      | 153/469 [00:04<00:08, 35.64it/s]
# Epoch 4 in training:  33%|███▎      | 157/469 [00:04<00:08, 36.13it/s]
# Epoch 4 in training:  34%|███▍      | 161/469 [00:05<00:08, 36.05it/s]
# Epoch 4 in training:  35%|███▌      | 165/469 [00:05<00:08, 36.24it/s]
# Epoch 4 in training:  36%|███▌      | 169/469 [00:05<00:08, 36.50it/s]
# Epoch 4 in training:  37%|███▋      | 173/469 [00:05<00:08, 36.12it/s]
# Epoch 4 in training:  38%|███▊      | 177/469 [00:05<00:08, 35.30it/s]
# Epoch 4 in training:  39%|███▊      | 181/469 [00:05<00:08, 35.90it/s]
# Epoch 4 in training:  39%|███▉      | 185/469 [00:05<00:08, 35.49it/s]
# Epoch 4 in training:  40%|████      | 189/469 [00:05<00:07, 35.64it/s]
# Epoch 4 in training:  41%|████      | 193/469 [00:05<00:07, 35.99it/s]
# Epoch 4 in training:  42%|████▏     | 197/469 [00:06<00:07, 36.00it/s]
# Epoch 4 in training:  43%|████▎     | 201/469 [00:06<00:07, 36.33it/s]
# Epoch 4 in training:  44%|████▎     | 205/469 [00:06<00:07, 36.57it/s]
# Epoch 4 in training:  45%|████▍     | 209/469 [00:06<00:07, 36.49it/s]
# Epoch 4 in training:  45%|████▌     | 213/469 [00:06<00:07, 34.96it/s]
# Epoch 4 in training:  46%|████▋     | 217/469 [00:06<00:07, 35.38it/s]
# Epoch 4 in training:  47%|████▋     | 221/469 [00:06<00:07, 35.04it/s]
# Epoch 4 in training:  48%|████▊     | 225/469 [00:06<00:06, 35.35it/s]
# Epoch 4 in training:  49%|████▉     | 229/469 [00:06<00:06, 35.79it/s]
# Epoch 4 in training:  50%|████▉     | 233/469 [00:07<00:06, 35.97it/s]
# Epoch 4 in training:  51%|█████     | 237/469 [00:07<00:06, 35.99it/s]
# Epoch 4 in training:  51%|█████▏    | 241/469 [00:07<00:06, 36.31it/s]
# Epoch 4 in training:  52%|█████▏    | 245/469 [00:07<00:06, 36.39it/s]
# Epoch 4 in training:  53%|█████▎    | 249/469 [00:07<00:06, 35.06it/s]
# Epoch 4 in training:  54%|█████▍    | 253/469 [00:07<00:06, 35.53it/s]
# Epoch 4 in training:  55%|█████▍    | 257/469 [00:07<00:06, 35.07it/s]
# Epoch 4 in training:  56%|█████▌    | 261/469 [00:07<00:05, 35.50it/s]
# Epoch 4 in training:  57%|█████▋    | 265/469 [00:07<00:05, 35.77it/s]
# Epoch 4 in training:  57%|█████▋    | 269/469 [00:08<00:05, 35.65it/s]
# Epoch 4 in training:  58%|█████▊    | 273/469 [00:08<00:05, 35.92it/s]
# Epoch 4 in training:  59%|█████▉    | 277/469 [00:08<00:05, 36.27it/s]
# Epoch 4 in training:  60%|█████▉    | 281/469 [00:08<00:05, 35.30it/s]
# Epoch 4 in training:  61%|██████    | 285/469 [00:08<00:05, 34.47it/s]
# Epoch 4 in training:  62%|██████▏   | 289/469 [00:08<00:05, 35.10it/s]
# Epoch 4 in training:  62%|██████▏   | 293/469 [00:08<00:05, 34.68it/s]
# Epoch 4 in training:  63%|██████▎   | 297/469 [00:08<00:04, 34.94it/s]
# Epoch 4 in training:  64%|██████▍   | 301/469 [00:08<00:04, 35.49it/s]
# Epoch 4 in training:  65%|██████▌   | 305/469 [00:09<00:04, 35.42it/s]
# Epoch 4 in training:  66%|██████▌   | 309/469 [00:09<00:04, 35.36it/s]
# Epoch 4 in training:  67%|██████▋   | 313/469 [00:09<00:04, 35.62it/s]
# Epoch 4 in training:  68%|██████▊   | 317/469 [00:09<00:04, 35.90it/s]
# Epoch 4 in training:  68%|██████▊   | 321/469 [00:09<00:04, 35.03it/s]
# Epoch 4 in training:  69%|██████▉   | 325/469 [00:09<00:04, 35.33it/s]
# Epoch 4 in training:  70%|███████   | 329/469 [00:09<00:03, 35.22it/s]
# Epoch 4 in training:  71%|███████   | 333/469 [00:09<00:03, 35.51it/s]
# Epoch 4 in training:  72%|███████▏  | 337/469 [00:09<00:03, 35.90it/s]
# Epoch 4 in training:  73%|███████▎  | 341/469 [00:10<00:03, 35.95it/s]
# Epoch 4 in training:  74%|███████▎  | 345/469 [00:10<00:03, 36.15it/s]
# Epoch 4 in training:  74%|███████▍  | 349/469 [00:10<00:03, 35.83it/s]
# Epoch 4 in training:  75%|███████▌  | 353/469 [00:10<00:03, 35.94it/s]
# Epoch 4 in training:  76%|███████▌  | 357/469 [00:10<00:03, 35.43it/s]
# Epoch 4 in training:  77%|███████▋  | 361/469 [00:10<00:03, 35.61it/s]
# Epoch 4 in training:  78%|███████▊  | 365/469 [00:10<00:02, 35.28it/s]
# Epoch 4 in training:  79%|███████▊  | 369/469 [00:10<00:02, 35.58it/s]
# Epoch 4 in training:  80%|███████▉  | 373/469 [00:10<00:02, 35.93it/s]
# Epoch 4 in training:  80%|████████  | 377/469 [00:11<00:02, 36.05it/s]
# Epoch 4 in training:  81%|████████  | 381/469 [00:11<00:02, 36.02it/s]
# Epoch 4 in training:  82%|████████▏ | 385/469 [00:11<00:02, 35.95it/s]
# Epoch 4 in training:  83%|████████▎ | 389/469 [00:11<00:02, 36.29it/s]
# Epoch 4 in training:  84%|████████▍ | 393/469 [00:11<00:02, 36.52it/s]
# Epoch 4 in training:  85%|████████▍ | 397/469 [00:11<00:02, 35.46it/s]
# Epoch 4 in training:  86%|████████▌ | 401/469 [00:11<00:01, 35.33it/s]
# Epoch 4 in training:  86%|████████▋ | 405/469 [00:11<00:01, 35.42it/s]
# Epoch 4 in training:  87%|████████▋ | 409/469 [00:11<00:01, 35.25it/s]
# Epoch 4 in training:  88%|████████▊ | 413/469 [00:12<00:01, 35.00it/s]
# Epoch 4 in training:  89%|████████▉ | 417/469 [00:12<00:01, 35.27it/s]
# Epoch 4 in training:  90%|████████▉ | 421/469 [00:12<00:01, 35.46it/s]
# Epoch 4 in training:  91%|█████████ | 425/469 [00:12<00:01, 35.74it/s]
# Epoch 4 in training:  91%|█████████▏| 429/469 [00:12<00:01, 36.07it/s]
# Epoch 4 in training:  92%|█████████▏| 433/469 [00:12<00:01, 34.55it/s]
# Epoch 4 in training:  93%|█████████▎| 437/469 [00:12<00:00, 34.86it/s]
# Epoch 4 in training:  94%|█████████▍| 441/469 [00:12<00:00, 35.29it/s]
# Epoch 4 in training:  95%|█████████▍| 445/469 [00:12<00:00, 35.60it/s]
# Epoch 4 in training:  96%|█████████▌| 449/469 [00:13<00:00, 36.05it/s]
# Epoch 4 in training:  97%|█████████▋| 453/469 [00:13<00:00, 35.67it/s]
# Epoch 4 in training:  97%|█████████▋| 457/469 [00:13<00:00, 30.86it/s]
# Epoch 4 in training:  98%|█████████▊| 461/469 [00:13<00:00, 29.91it/s]
# Epoch 4 in training:  99%|█████████▉| 465/469 [00:13<00:00, 28.82it/s]
# Epoch 4 in training: 100%|█████████▉| 468/469 [00:13<00:00, 28.47it/s]
# Training:  80%|████████  | 4/5 [00:54<00:13, 13.77s/it]
# Epoch 4/5 loss: 0.40
# Epoch 5 in training:   0%|          | 0/469 [00:00<?, ?it/s]
# Epoch 5 in training:   1%|          | 3/469 [00:00<00:16, 28.64it/s]
# Epoch 5 in training:   1%|▏         | 6/469 [00:00<00:16, 27.61it/s]
# Epoch 5 in training:   2%|▏         | 9/469 [00:00<00:16, 27.41it/s]
# Epoch 5 in training:   3%|▎         | 12/469 [00:00<00:16, 27.97it/s]
# Epoch 5 in training:   3%|▎         | 16/469 [00:00<00:15, 29.03it/s]
# Epoch 5 in training:   4%|▍         | 20/469 [00:00<00:15, 29.66it/s]
# Epoch 5 in training:   5%|▍         | 23/469 [00:00<00:15, 28.35it/s]
# Epoch 5 in training:   6%|▌         | 26/469 [00:00<00:16, 26.23it/s]
# Epoch 5 in training:   6%|▌         | 29/469 [00:01<00:16, 26.80it/s]
# Epoch 5 in training:   7%|▋         | 32/469 [00:01<00:17, 25.27it/s]
# Epoch 5 in training:   7%|▋         | 35/469 [00:01<00:17, 24.81it/s]
# Epoch 5 in training:   8%|▊         | 38/469 [00:01<00:17, 24.19it/s]
# Epoch 5 in training:   9%|▉         | 42/469 [00:01<00:15, 27.68it/s]
# Epoch 5 in training:  10%|▉         | 46/469 [00:01<00:13, 30.33it/s]
# Epoch 5 in training:  11%|█         | 50/469 [00:01<00:13, 32.08it/s]
# Epoch 5 in training:  12%|█▏        | 54/469 [00:01<00:13, 31.73it/s]
# Epoch 5 in training:  12%|█▏        | 58/469 [00:02<00:12, 33.01it/s]
# Epoch 5 in training:  13%|█▎        | 62/469 [00:02<00:11, 34.02it/s]
# Epoch 5 in training:  14%|█▍        | 66/469 [00:02<00:11, 34.76it/s]
# Epoch 5 in training:  15%|█▍        | 70/469 [00:02<00:11, 35.40it/s]
# Epoch 5 in training:  16%|█▌        | 74/469 [00:02<00:11, 35.63it/s]
# Epoch 5 in training:  17%|█▋        | 78/469 [00:02<00:10, 36.18it/s]
# Epoch 5 in training:  17%|█▋        | 82/469 [00:02<00:10, 36.42it/s]
# Epoch 5 in training:  18%|█▊        | 86/469 [00:02<00:10, 36.40it/s]
# Epoch 5 in training:  19%|█▉        | 90/469 [00:02<00:10, 36.08it/s]
# Epoch 5 in training:  20%|██        | 94/469 [00:03<00:10, 34.93it/s]
# Epoch 5 in training:  21%|██        | 98/469 [00:03<00:10, 35.52it/s]
# Epoch 5 in training:  22%|██▏       | 102/469 [00:03<00:10, 35.96it/s]
# Epoch 5 in training:  23%|██▎       | 106/469 [00:03<00:09, 36.33it/s]
# Epoch 5 in training:  23%|██▎       | 110/469 [00:03<00:09, 36.22it/s]
# Epoch 5 in training:  24%|██▍       | 114/469 [00:03<00:09, 36.34it/s]
# Epoch 5 in training:  25%|██▌       | 118/469 [00:03<00:09, 36.61it/s]
# Epoch 5 in training:  26%|██▌       | 122/469 [00:03<00:09, 36.75it/s]
# Epoch 5 in training:  27%|██▋       | 126/469 [00:03<00:09, 36.31it/s]
# Epoch 5 in training:  28%|██▊       | 130/469 [00:04<00:09, 35.24it/s]
# Epoch 5 in training:  29%|██▊       | 134/469 [00:04<00:09, 35.47it/s]
# Epoch 5 in training:  29%|██▉       | 138/469 [00:04<00:09, 35.60it/s]
# Epoch 5 in training:  30%|███       | 142/469 [00:04<00:09, 35.78it/s]
# Epoch 5 in training:  31%|███       | 146/469 [00:04<00:08, 36.00it/s]
# Epoch 5 in training:  32%|███▏      | 150/469 [00:04<00:08, 36.18it/s]
# Epoch 5 in training:  33%|███▎      | 154/469 [00:04<00:08, 36.51it/s]
# Epoch 5 in training:  34%|███▎      | 158/469 [00:04<00:08, 35.50it/s]
# Epoch 5 in training:  35%|███▍      | 162/469 [00:04<00:08, 35.35it/s]
# Epoch 5 in training:  35%|███▌      | 166/469 [00:05<00:09, 33.00it/s]
# Epoch 5 in training:  36%|███▌      | 170/469 [00:05<00:08, 33.56it/s]
# Epoch 5 in training:  37%|███▋      | 174/469 [00:05<00:08, 34.15it/s]
# Epoch 5 in training:  38%|███▊      | 178/469 [00:05<00:08, 34.81it/s]
# Epoch 5 in training:  39%|███▉      | 182/469 [00:05<00:08, 34.88it/s]
# Epoch 5 in training:  40%|███▉      | 186/469 [00:05<00:07, 35.49it/s]
# Epoch 5 in training:  41%|████      | 190/469 [00:05<00:07, 35.54it/s]
# Epoch 5 in training:  41%|████▏     | 194/469 [00:05<00:07, 35.55it/s]
# Epoch 5 in training:  42%|████▏     | 198/469 [00:05<00:07, 35.80it/s]
# Epoch 5 in training:  43%|████▎     | 202/469 [00:06<00:07, 34.56it/s]
# Epoch 5 in training:  44%|████▍     | 206/469 [00:06<00:07, 34.92it/s]
# Epoch 5 in training:  45%|████▍     | 210/469 [00:06<00:07, 35.32it/s]
# Epoch 5 in training:  46%|████▌     | 214/469 [00:06<00:07, 35.77it/s]
# Epoch 5 in training:  46%|████▋     | 218/469 [00:06<00:07, 35.75it/s]
# Epoch 5 in training:  47%|████▋     | 222/469 [00:06<00:06, 35.86it/s]
# Epoch 5 in training:  48%|████▊     | 226/469 [00:06<00:06, 35.16it/s]
# Epoch 5 in training:  49%|████▉     | 230/469 [00:06<00:06, 35.21it/s]
# Epoch 5 in training:  50%|████▉     | 234/469 [00:06<00:06, 35.23it/s]
# Epoch 5 in training:  51%|█████     | 238/469 [00:07<00:06, 34.60it/s]
# Epoch 5 in training:  52%|█████▏    | 242/469 [00:07<00:06, 34.90it/s]
# Epoch 5 in training:  52%|█████▏    | 246/469 [00:07<00:06, 35.43it/s]
# Epoch 5 in training:  53%|█████▎    | 250/469 [00:07<00:06, 35.91it/s]
# Epoch 5 in training:  54%|█████▍    | 254/469 [00:07<00:06, 35.77it/s]
# Epoch 5 in training:  55%|█████▌    | 258/469 [00:07<00:05, 36.07it/s]
# Epoch 5 in training:  56%|█████▌    | 262/469 [00:07<00:05, 36.39it/s]
# Epoch 5 in training:  57%|█████▋    | 266/469 [00:07<00:05, 35.45it/s]
# Epoch 5 in training:  58%|█████▊    | 270/469 [00:07<00:05, 35.77it/s]
# Epoch 5 in training:  58%|█████▊    | 274/469 [00:08<00:05, 34.79it/s]
# Epoch 5 in training:  59%|█████▉    | 278/469 [00:08<00:05, 34.97it/s]
# Epoch 5 in training:  60%|██████    | 282/469 [00:08<00:05, 35.27it/s]
# Epoch 5 in training:  61%|██████    | 286/469 [00:08<00:05, 35.75it/s]
# Epoch 5 in training:  62%|██████▏   | 290/469 [00:08<00:04, 35.83it/s]
# Epoch 5 in training:  63%|██████▎   | 294/469 [00:08<00:04, 36.08it/s]
# Epoch 5 in training:  64%|██████▎   | 298/469 [00:08<00:04, 36.16it/s]
# Epoch 5 in training:  64%|██████▍   | 302/469 [00:08<00:04, 35.57it/s]
# Epoch 5 in training:  65%|██████▌   | 306/469 [00:08<00:04, 35.68it/s]
# Epoch 5 in training:  66%|██████▌   | 310/469 [00:09<00:04, 35.98it/s]
# Epoch 5 in training:  67%|██████▋   | 314/469 [00:09<00:04, 34.92it/s]
# Epoch 5 in training:  68%|██████▊   | 318/469 [00:09<00:04, 35.22it/s]
# Epoch 5 in training:  69%|██████▊   | 322/469 [00:09<00:04, 35.60it/s]
# Epoch 5 in training:  70%|██████▉   | 326/469 [00:09<00:03, 35.82it/s]
# Epoch 5 in training:  70%|███████   | 330/469 [00:09<00:03, 36.24it/s]
# Epoch 5 in training:  71%|███████   | 334/469 [00:09<00:03, 36.59it/s]
# Epoch 5 in training:  72%|███████▏  | 338/469 [00:09<00:03, 36.09it/s]
# Epoch 5 in training:  73%|███████▎  | 342/469 [00:09<00:03, 36.23it/s]
# Epoch 5 in training:  74%|███████▍  | 346/469 [00:10<00:03, 36.45it/s]
# Epoch 5 in training:  75%|███████▍  | 350/469 [00:10<00:03, 34.90it/s]
# Epoch 5 in training:  75%|███████▌  | 354/469 [00:10<00:03, 35.40it/s]
# Epoch 5 in training:  76%|███████▋  | 358/469 [00:10<00:03, 35.64it/s]
# Epoch 5 in training:  77%|███████▋  | 362/469 [00:10<00:02, 35.79it/s]
# Epoch 5 in training:  78%|███████▊  | 366/469 [00:10<00:02, 36.26it/s]
# Epoch 5 in training:  79%|███████▉  | 370/469 [00:10<00:02, 36.51it/s]
# Epoch 5 in training:  80%|███████▉  | 374/469 [00:10<00:02, 35.80it/s]
# Epoch 5 in training:  81%|████████  | 378/469 [00:10<00:02, 35.61it/s]
# Epoch 5 in training:  81%|████████▏ | 382/469 [00:11<00:02, 35.93it/s]
# Epoch 5 in training:  82%|████████▏ | 386/469 [00:11<00:02, 34.73it/s]
# Epoch 5 in training:  83%|████████▎ | 390/469 [00:11<00:02, 35.18it/s]
# Epoch 5 in training:  84%|████████▍ | 394/469 [00:11<00:02, 35.49it/s]
# Epoch 5 in training:  85%|████████▍ | 398/469 [00:11<00:02, 29.80it/s]
# Epoch 5 in training:  86%|████████▌ | 402/469 [00:11<00:02, 28.57it/s]
# Epoch 5 in training:  86%|████████▋ | 405/469 [00:11<00:02, 27.73it/s]
# Epoch 5 in training:  87%|████████▋ | 408/469 [00:12<00:02, 27.27it/s]
# Epoch 5 in training:  88%|████████▊ | 411/469 [00:12<00:02, 26.84it/s]
# Epoch 5 in training:  88%|████████▊ | 414/469 [00:12<00:02, 25.78it/s]
# Epoch 5 in training:  89%|████████▉ | 417/469 [00:12<00:01, 26.06it/s]
# Epoch 5 in training:  90%|████████▉ | 420/469 [00:12<00:01, 26.83it/s]
# Epoch 5 in training:  90%|█████████ | 423/469 [00:12<00:01, 27.31it/s]
# Epoch 5 in training:  91%|█████████ | 427/469 [00:12<00:01, 28.35it/s]
# Epoch 5 in training:  92%|█████████▏| 430/469 [00:12<00:01, 27.56it/s]
# Epoch 5 in training:  92%|█████████▏| 433/469 [00:12<00:01, 26.32it/s]
# Epoch 5 in training:  93%|█████████▎| 436/469 [00:13<00:01, 26.20it/s]
# Epoch 5 in training:  94%|█████████▎| 439/469 [00:13<00:01, 25.04it/s]
# Epoch 5 in training:  94%|█████████▍| 442/469 [00:13<00:01, 23.31it/s]
# Epoch 5 in training:  95%|█████████▍| 445/469 [00:13<00:01, 22.72it/s]
# Epoch 5 in training:  96%|█████████▌| 448/469 [00:13<00:00, 23.99it/s]
# Epoch 5 in training:  96%|█████████▋| 452/469 [00:13<00:00, 26.92it/s]
# Epoch 5 in training:  97%|█████████▋| 456/469 [00:13<00:00, 29.39it/s]
# Epoch 5 in training:  98%|█████████▊| 460/469 [00:13<00:00, 31.35it/s]
# Epoch 5 in training:  99%|█████████▉| 464/469 [00:14<00:00, 32.75it/s]
# Epoch 5 in training: 100%|█████████▉| 468/469 [00:14<00:00, 33.68it/s]
# Training: 100%|██████████| 5/5 [01:09<00:00, 13.83s/it]
# Epoch 5/5 loss: 0.38
# Testing: 100%|██████████| 79/79 [00:01<00:00, 52.75it/s]
# Test loss: 0.39
# Test accuracy: 85.29%
# Saved Trained Model.

# %% [markdown]
# ### Describe what you did and discovered here
# In this cell you should write all the settings tried and performances you obtained. Report what you did and what you discovered from the trials.
# You can write in Korean and English

# %% [markdown]
#     patch_size=5
#     embed_dim=64
#     depth=6
#     num_heads=16
#     mlp_ratio=4
#
#     Test accuracy: 82.28%
#
#
#     patch_size=5
#     embed_dim=32
#     depth=6
#     num_heads=16
#     mlp_ratio=4
#
#     Test accuracy: 84.65%
#
#
#     patch_size=5
#     embed_dim=16
#     depth=6
#     num_heads=16
#     mlp_ratio=4
#
#     Test accuracy: 83.44%
#
#     patch_size는 유지한 채 embed_dim 을 변화시켰는데 32일때 정확도가 가장 높았다.
#
#
#     patch_size=4
#     embed_dim=32
#     depth=6
#     num_heads=16
#     mlp_ratio=4
#
#     Test accuracy: 84.43%
#
#     patch_size를 5에서 4로 줄이고 가장 좋은 결과를 얻었던 embed_dim을 유지하며 수행했더니 비슷한 결과를 얻을 수 있었다.
#
#
#     patch_size=4
#     embed_dim=128
#     depth=6
#     num_heads=16
#     mlp_ratio=4
#
#     Test accuracy: 75.83%
#
#     embed_dim이 지나치게 높을 경우 정확도가 상당히 떨어짐을 알 수 있다.
#
#
#     patch_size=4
#     embed_dim=32
#     depth=5
#     num_heads=16
#     mlp_ratio=4
#
#     Test accuracy: 85.29%
#
#     depth를 줄이니 학습 과정이 간결해지고 속도도 빨라짐과 동시에 정확도도 더욱 높아졌다. 그리 크지않은 데이터로 학습을 진행하다보니 너무 복잡하게 학습하면 오히려 정확도가 떨어지게 되는 것 같다.
